# %%
import pandas as pd 
import seaborn as sns

# %%
# importing data frame 
dtf= sns.load_dataset('penguins')
dtf
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# renaming the columns 
dtf.columns= ['species', 'island', 'b_len', 'b_dep', 'f_len', 'bm_g', 'sex']
print(dtf.head())
# Out:
#   species     island  b_len  b_dep  f_len    bm_g     sex
# 0  Adelie  Torgersen   39.1   18.7  181.0  3750.0    Male
# 1  Adelie  Torgersen   39.5   17.4  186.0  3800.0  Female
# 2  Adelie  Torgersen   40.3   18.0  195.0  3250.0  Female
# 3  Adelie  Torgersen    NaN    NaN    NaN     NaN     NaN
# 4  Adelie  Torgersen   36.7   19.3  193.0  3450.0  Female

# %%
# correlation matrix form
matrix1= dtf.corr() 
print(matrix1)
# Out:
#           b_len     b_dep     f_len      bm_g
# b_len  1.000000 -0.235053  0.656181  0.595110
# b_dep -0.235053  1.000000 -0.583851 -0.471916
# f_len  0.656181 -0.583851  1.000000  0.871202
# bm_g   0.595110 -0.471916  0.871202  1.000000
# /var/folders/jd/9_5vkw3n2xs82y4zq9sgqwwm0000gp/T/ipykernel_6322/2252337714.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix1= dtf.corr()

# %%
# make the decimals round 
matrix1= dtf.corr().round(2)
print(matrix1)
# Out:
#        b_len  b_dep  f_len  bm_g
# b_len   1.00  -0.24   0.66  0.60
# b_dep  -0.24   1.00  -0.58 -0.47
# f_len   0.66  -0.58   1.00  0.87
# bm_g    0.60  -0.47   0.87  1.00
# /var/folders/jd/9_5vkw3n2xs82y4zq9sgqwwm0000gp/T/ipykernel_6322/3298599025.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix1= dtf.corr().round(2)

# %%
#visualtion correlation 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# building the plot 
matrix1= dtf.corr().round(2) 
sns.heatmap(matrix1, annot=True)
plt.show
# Out:
# /var/folders/jd/9_5vkw3n2xs82y4zq9sgqwwm0000gp/T/ipykernel_6322/1480220847.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix1= dtf.corr().round(2)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# changing the color 
# building the plot 
matrix1= dtf.corr().round(2) 
sns.heatmap(matrix1, annot=True, vmax=1, vmin=-1, center=0, cmap='vlag')
plt.show
# Out:
# /var/folders/jd/9_5vkw3n2xs82y4zq9sgqwwm0000gp/T/ipykernel_6322/2442442465.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix1= dtf.corr().round(2)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# showing half of the heatmap 
matrix1= dtf.corr().round(2) 
mask= np.triu(np.ones_like(matrix1, dtype=bool))
sns.heatmap(matrix1, annot=True, vmax=1, vmin=-1, center=0, cmap='vlag', mask=mask)
plt.show
# Out:
# /var/folders/jd/9_5vkw3n2xs82y4zq9sgqwwm0000gp/T/ipykernel_6322/300410205.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix1= dtf.corr().round(2)
# <function matplotlib.pyplot.show(close=None, block=None)>
